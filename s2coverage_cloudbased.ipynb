# %% [markdown]
# ## Calculation of Coverage

# %%
input_dir = '/ds/images/AI4EO/EnhancedS2Agriculture/preprocessed/train'

# %%
from src.coverage_analysis.dataset_coverage_analysis import analyse_dataset

strategy= 'by_clouds' #'by_classes' #'by_clouds'
idx_targets = [8,9,3] #[4,5] #[8,9,3]
min_spatial_coverage=50
min_temporal_coverage=50      
boundary_mask=None
results = analyse_dataset(input_dir = input_dir, idx_targets = idx_targets, boundary_mask = boundary_mask,
                            strategy = strategy, min_spatial_coverage = min_spatial_coverage, 
                            min_temporal_coverage = min_temporal_coverage)

# %% [markdown]
# ## Plots

# %%
input_dir = './coverage/ai4eo/'

# %%
import pandas as pd
from src.utils.plots import plot_coverage_perc

df_stats = pd.read_csv(f"{input_dir}/assesment_report_clouds_70_70.csv", index_col=0)
df_stats.head()
# Out:
#              num_timesteps  num_timesteps_missing  avg_spatial_coverage  \
# filename
# eopatch-841             38                     36             89.680168
# eopatch-781             38                     38             87.406063
# eopatch-718             38                     38             90.185642
# eopatch-804             38                     38             89.544000
# eopatch-903             38                     37             86.175158
#
#              num_timesteps_abovecov  temporal_coverage assesment_temporal  \
# filename
# eopatch-841                      34          89.473684               high
# eopatch-781                      33          86.842105               high
# eopatch-718                      33          86.842105               high
# eopatch-804                      31          81.578947               high
# eopatch-903                      30          78.947368               high
#
#             assesment_spatial
# filename
# eopatch-841              high
# eopatch-781              high
# eopatch-718              high
# eopatch-804              high
# eopatch-903              high

# %%
#low coverage fields based on spatial assessment
df_stats[df_stats["assesment_spatial"] == "low"]
# Out:
# Empty DataFrame
# Columns: [num_timesteps, num_timesteps_missing, avg_spatial_coverage, num_timesteps_abovecov, temporal_coverage, assesment_temporal, assesment_spatial]
# Index: []

# %%
#low coverage fields based on temporal assessment
df_stats[df_stats["assesment_temporal"] == "low"]
# Out:
#              num_timesteps  num_timesteps_missing  avg_spatial_coverage  \
# filename
# eopatch-908             38                     34             80.265895
#
#              num_timesteps_abovecov  temporal_coverage assesment_temporal  \
# filename
# eopatch-908                      26          68.421053                low
#
#             assesment_spatial
# filename
# eopatch-908              high

# %%
plot_coverage_perc(df_stats, "avg_spatial_coverage")

plot_coverage_perc(df_stats, "temporal_coverage")
# Out:
# num_timesteps             38.000000
# num_timesteps_missing     27.375000
# avg_spatial_coverage      79.265621
# num_timesteps_abovecov    19.000000
# temporal_coverage         69.736842
# dtype: float64

# %% [markdown]
# ### Attach metrics results into Coverage

# %%
import pandas as pd
from src.coverage_analysis.visualizer import add_topk_column, plot_col_categorization

folder_results = "./result/ai4eo/"

df_metrics_p_patch_train = pd.read_csv(f"{folder_results}/train_preds_patchs.csv", index_col=0)
df_metrics_p_patch_test = pd.read_csv(f"{folder_results}/test_preds_patchs.csv", index_col=0)
df_metrics_p_patch_test.head()
# Out:
#                   MCC       ACC
# eopatch-298  0.825550  0.964864
# eopatch-342  0.826631  0.962379
# eopatch-343  0.825348  0.951240
# eopatch-381  0.666570  0.917755
# eopatch-404  0.737810  0.950077

# %%
df_stats_test = df_stats.loc[df_metrics_p_patch_test.index]

_ = plot_col_categorization(df_stats_test, df_metrics_p_patch_test, col="assesment_temporal")
# Out:
#                      MCC                                                    \
#                    count      mean       std       min       25%       50%
# assesment_temporal
# high                19.0  0.785465  0.055856  0.666570  0.741563  0.799981
# low                  1.0  0.711042       NaN  0.711042  0.711042  0.711042
#
#                                          ACC                                \
#                          75%       max count      mean       std       min
# assesment_temporal
# high                0.826092  0.858167  19.0  0.929426  0.041174  0.854398
# low                 0.711042  0.711042   1.0  0.926882       NaN  0.926882
#
#
#                          25%       50%       75%       max
# assesment_temporal
# high                0.892358  0.949551  0.963564  0.978436
# low                 0.926882  0.926882  0.926882  0.926882

# %% [markdown]
# ### Consideron top-K images

# %%
df_stats_test = df_stats.loc[df_metrics_p_patch_test.index]
add_topk_column(df_stats_test, k=5, column="temporal_coverage")

data_attached = plot_col_categorization(df_stats_test, df_metrics_p_patch_test, col="assesment_top5")
# Out:
# Limit temporal_coverage is 78.94736842105263
#                  MCC                                                    \
#                count      mean       std       min       25%       50%
# assesment_top5
# high            12.0  0.803903  0.053266  0.666570  0.792251  0.825449
# low              8.0  0.748506  0.047024  0.707902  0.710491  0.730878
#
#                                      ACC                                \
#                      75%       max count      mean       std       min
# assesment_top5
# high            0.829880  0.858167  12.0  0.954831  0.017163  0.917755
# low             0.775656  0.830981   8.0  0.890999  0.033216  0.854398
#
#
#                      25%       50%       75%       max
# assesment_top5
# high            0.948487  0.960420  0.964914  0.978436
# low             0.871820  0.881597  0.907112  0.949551

# %%
data_attached
# Out:
#              num_timesteps  num_timesteps_missing  avg_spatial_coverage  \
# eopatch-298             19                     19             91.961432
# eopatch-342             19                     18             92.704421
# eopatch-343             19                     19             92.496674
# eopatch-381             19                     19             91.815916
# eopatch-404             19                     19             96.207579
# eopatch-577             48                     48             81.572300
# eopatch-644             38                     36             88.045305
# eopatch-672             38                     38             87.066821
# eopatch-718             38                     38             90.185642
# eopatch-740             38                     38             84.448379
# eopatch-818             38                     37             88.646611
# eopatch-823             38                     32             88.446063
# eopatch-825             38                     38             85.853474
# eopatch-869             38                     37             84.509558
# eopatch-877             38                     38             88.498568
# eopatch-880             38                     37             85.907284
# eopatch-893             38                     38             82.738526
# eopatch-904             38                     38             83.932421
# eopatch-905             38                     35             81.785853
# eopatch-908             38                     34             80.265895
#
#              num_timesteps_abovecov  temporal_coverage assesment_temporal  \
# eopatch-298                      18          94.736842               high
# eopatch-342                      18          94.736842               high
# eopatch-343                      18          94.736842               high
# eopatch-381                      18          94.736842               high
# eopatch-404                      18          94.736842               high
# eopatch-577                      38          79.166667               high
# eopatch-644                      33          86.842105               high
# eopatch-672                      33          86.842105               high
# eopatch-718                      33          86.842105               high
# eopatch-740                      30          78.947368               high
# eopatch-818                      33          86.842105               high
# eopatch-823                      32          84.210526               high
# eopatch-825                      30          78.947368               high
# eopatch-869                      30          78.947368               high
# eopatch-877                      32          84.210526               high
# eopatch-880                      29          76.315789               high
# eopatch-893                      28          73.684211               high
# eopatch-904                      27          71.052632               high
# eopatch-905                      28          73.684211               high
# eopatch-908                      26          68.421053                low
#
#             assesment_spatial assesment_top5       MCC       ACC
# eopatch-298              high           high  0.825550  0.964864
# eopatch-342              high           high  0.826631  0.962379
# eopatch-343              high           high  0.825348  0.951240
# eopatch-381              high           high  0.666570  0.917755
# eopatch-404              high           high  0.737810  0.950077
# eopatch-577              high           high  0.791887  0.964748
# eopatch-644              high           high  0.825554  0.943717
# eopatch-672              high           high  0.841769  0.969855
# eopatch-718              high           high  0.815547  0.965065
# eopatch-740              high            low  0.830981  0.949551
# eopatch-818              high           high  0.792372  0.958461
# eopatch-823              high           high  0.858167  0.978436
# eopatch-825              high            low  0.745316  0.878999
# eopatch-869              high            low  0.708837  0.876919
# eopatch-877              high           high  0.839627  0.931380
# eopatch-880              high            low  0.707902  0.854398
# eopatch-893              high            low  0.767548  0.884195
# eopatch-904              high            low  0.716440  0.856525
# eopatch-905              high            low  0.799981  0.900521
# eopatch-908              high            low  0.711042  0.926882

# %% [markdown]
# what happened with eopatch-880	??

# %%
df_stats_test = df_stats.loc[df_metrics_p_patch_test.index]
add_topk_column(df_stats_test, k=5, column="avg_spatial_coverage")

plot_col_categorization(df_stats_test, df_metrics_p_patch_test, col="assesment_top5")
# Out:
# Limit avg_spatial_coverage is 84.44837894736841
#                  MCC                                                    \
#                count      mean       std       min       25%       50%
# assesment_top5
# high            14.0  0.786928  0.061217  0.666570  0.739687  0.820448
# low              6.0  0.769646  0.047847  0.711042  0.729217  0.779718
#
#                                      ACC                                \
#                      75%       max count      mean       std       min
# assesment_top5
# high            0.826361  0.858167  14.0  0.935967  0.039290  0.854398
# low             0.797957  0.830981   6.0  0.913737  0.040934  0.856525
#
#
#                      25%       50%       75%       max
# assesment_top5
# high            0.921162  0.950659  0.964243  0.978436
# low             0.888277  0.913702  0.943884  0.964748
#              num_timesteps  num_timesteps_missing  avg_spatial_coverage  \
# eopatch-298             19                     19             91.961432
# eopatch-342             19                     18             92.704421
# eopatch-343             19                     19             92.496674
# eopatch-381             19                     19             91.815916
# eopatch-404             19                     19             96.207579
# eopatch-577             48                     48             81.572300
# eopatch-644             38                     36             88.045305
# eopatch-672             38                     38             87.066821
# eopatch-718             38                     38             90.185642
# eopatch-740             38                     38             84.448379
# eopatch-818             38                     37             88.646611
# eopatch-823             38                     32             88.446063
# eopatch-825             38                     38             85.853474
# eopatch-869             38                     37             84.509558
# eopatch-877             38                     38             88.498568
# eopatch-880             38                     37             85.907284
# eopatch-893             38                     38             82.738526
# eopatch-904             38                     38             83.932421
# eopatch-905             38                     35             81.785853
# eopatch-908             38                     34             80.265895
#
#              num_timesteps_abovecov  temporal_coverage assesment_temporal  \
# eopatch-298                      18          94.736842               high
# eopatch-342                      18          94.736842               high
# eopatch-343                      18          94.736842               high
# eopatch-381                      18          94.736842               high
# eopatch-404                      18          94.736842               high
# eopatch-577                      38          79.166667               high
# eopatch-644                      33          86.842105               high
# eopatch-672                      33          86.842105               high
# eopatch-718                      33          86.842105               high
# eopatch-740                      30          78.947368               high
# eopatch-818                      33          86.842105               high
# eopatch-823                      32          84.210526               high
# eopatch-825                      30          78.947368               high
# eopatch-869                      30          78.947368               high
# eopatch-877                      32          84.210526               high
# eopatch-880                      29          76.315789               high
# eopatch-893                      28          73.684211               high
# eopatch-904                      27          71.052632               high
# eopatch-905                      28          73.684211               high
# eopatch-908                      26          68.421053                low
#
#             assesment_spatial assesment_top5       MCC       ACC
# eopatch-298              high           high  0.825550  0.964864
# eopatch-342              high           high  0.826631  0.962379
# eopatch-343              high           high  0.825348  0.951240
# eopatch-381              high           high  0.666570  0.917755
# eopatch-404              high           high  0.737810  0.950077
# eopatch-577              high            low  0.791887  0.964748
# eopatch-644              high           high  0.825554  0.943717
# eopatch-672              high           high  0.841769  0.969855
# eopatch-718              high           high  0.815547  0.965065
# eopatch-740              high            low  0.830981  0.949551
# eopatch-818              high           high  0.792372  0.958461
# eopatch-823              high           high  0.858167  0.978436
# eopatch-825              high           high  0.745316  0.878999
# eopatch-869              high           high  0.708837  0.876919
# eopatch-877              high           high  0.839627  0.931380
# eopatch-880              high           high  0.707902  0.854398
# eopatch-893              high            low  0.767548  0.884195
# eopatch-904              high            low  0.716440  0.856525
# eopatch-905              high            low  0.799981  0.900521
# eopatch-908              high            low  0.711042  0.926882
